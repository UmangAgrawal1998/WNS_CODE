# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("wns.csv")

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# 5            58896          Analytics   region_2        Bachelor's      m
# 6            20379         Operations  region_20        Bachelor's      f
# 7            16290         Operations  region_34  Master's & above      m
# 8            73202          Analytics  region_20        Bachelor's      m
# 9            28911  Sales & Marketing   region_1  Master's & above      m
# 10           29934         Technology  region_23               NaN      m
# 11           49017  Sales & Marketing   region_7        Bachelor's      f
# ...

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
xvar=df[["department","region","education","no_of_trainings","age","previous_year_rating","length_of_service","KPIs_met >80%","awards_won?","avg_training_score"]]

# %%
xvar.head()
# Out:
#           department     region         education  no_of_trainings  age  \
# 0  Sales & Marketing   region_7  Master's & above                1   35
# 1         Operations  region_22        Bachelor's                1   30
# 2  Sales & Marketing  region_19        Bachelor's                1   34
# 3  Sales & Marketing  region_23        Bachelor's                2   39
# 4         Technology  region_26        Bachelor's                1   45
#
#    previous_year_rating  length_of_service  KPIs_met >80%  awards_won?  \
# 0                   5.0                  8              1            0
# 1                   5.0                  4              0            0
# 2                   3.0                  7              0            0
# 3                   1.0                 10              0            0
# 4                   3.0                  2              0            0
#
#    avg_training_score
# 0                  49
# 1                  60
# 2                  50
# ...

# %%
yvar=df["is_promoted"]

# %%
xvar["education"].isna().sum()
# Out:
# 2409

# %%
xvar["education"]=xvar["education"].fillna("school")
# Out:
# C:\Users\User\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
xvar[xvar["education"]=="school"]
# Out:
#               department     region education  no_of_trainings  age  \
# 10            Technology  region_23    school                1   30
# 21            Operations  region_15    school                1   41
# 32     Sales & Marketing   region_7    school                1   24
# 43     Sales & Marketing   region_2    school                3   24
# 82     Sales & Marketing   region_2    school                2   25
# 87     Sales & Marketing   region_2    school                1   39
# 90     Sales & Marketing   region_2    school                1   20
# 189           Operations   region_2    school                1   33
# 204           Operations  region_16    school                1   31
# 231    Sales & Marketing  region_26    school                1   22
# 245                  R&D   region_2    school                1   25
# 277            Analytics  region_27    school                1   31
# 323    Sales & Marketing   region_2    school                1   22
# ...

# %%
xvar["education"].isna().sum()
# Out:
# 0

# %%
xvar["no_of_trainings"].nunique()
# Out:
# 10

# %%
xvar["previous_year_rating"].nunique()
# Out:
# 5

# %%
sns.countplot(x="department",data=df[df["is_promoted"]==1])
df["department"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8befd6e7beee> in <module>()
# ----> 1 sns.countplot(x="department",data=df[df["is_promoted"]==1])
#       2 df["department"].value_counts()
#
# NameError: name 'sns' is not defined

# %%
import matplotlib.pyplot as plt

# %%
xvar["education"].value_counts()
# Out:
# Bachelor's          36669
# Master's & above    14925
# school               2409
# Below Secondary       805
# Name: education, dtype: int64

# %%
import seaborn as sns

# %%
data=df[df["is_promoted"]==1]

# %%
sns.countplot(x="education",data=df[df["is_promoted"]==1])
df["education"].value_counts()
# Out:
# Bachelor's          36669
# Master's & above    14925
# Below Secondary       805
# Name: education, dtype: int64

# %%
sns.countplot(x="gender",data=data)
df["gender"].value_counts()
# Out:
# m    38496
# f    16312
# Name: gender, dtype: int64

# %%
sns.countplot(x="recruitment_channel",hue="is_promoted",data=data)
df["recruitment_channel"].value_counts()
# Out:
# other       30446
# sourcing    23220
# referred     1142
# Name: recruitment_channel, dtype: int64

# %%
sns.countplot(x="awards_won?",data=df)

# %%
sns.countplot(x="no_of_trainings",data=data)

# %%
plt.scatter(x='avg_training_score',y='no_of_trainings',data=data)

# %%
sns.countplot(x='avg_training_score',data=df,hue='is_promoted')

# %%
plt.hist(x='avg_training_score',data=data)
# Out:
# (array([ 87., 562., 421., 721., 365., 499., 553., 707., 477., 276.]),
#  array([41. , 46.8, 52.6, 58.4, 64.2, 70. , 75.8, 81.6, 87.4, 93.2, 99. ]),
#  <a list of 10 Patch objects>)

# %%
sns.countplot(x="length_of_service",data=df,hue="is_promoted")

# %%
sns.countplot(x="previous_year_rating",data=df,hue="is_promoted")
df["previous_year_rating"].value_counts()
# Out:
# 3.0    18618
# 5.0    11741
# 4.0     9877
# 1.0     6223
# 2.0     4225
# Name: previous_year_rating, dtype: int64

# %%
xvar["awards_won?"].value_counts()
# Out:
# 0    53538
# 1     1270
# Name: awards_won?, dtype: int64

# %%
xvar["KPIs_met >80%"].value_counts()
# Out:
# 0    35517
# 1    19291
# Name: KPIs_met >80%, dtype: int64

# %%
sns.countplot(x="KPIs_met >80%",data=data)

# %%
sns.countplot(x="region",data=data)

# %%
xvar=df[["department","education","no_of_trainings","age","previous_year_rating","length_of_service","KPIs_met >80%"]]

# %%
xvar[["region"]].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-440-b8f4d11888e3> in <module>()
# ----> 1 xvar[["region"]].nunique()
#
# C:\Users\User\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# C:\Users\User\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelBinarizer

lb_make = LabelEncoder()

# %%
xvar.head()
# Out:
#           department         education  no_of_trainings  age  \
# 0  Sales & Marketing  Master's & above                1   35
# 1         Operations        Bachelor's                1   30
# 2  Sales & Marketing        Bachelor's                1   34
# 3  Sales & Marketing        Bachelor's                2   39
# 4         Technology        Bachelor's                1   45
#
#    previous_year_rating  length_of_service  KPIs_met >80%
# 0                   5.0                  8              1
# 1                   5.0                  4              0
# 2                   3.0                  7              0
# 3                   1.0                 10              0
# 4                   3.0                  2              0

# %%
xvar["education"]=xvar["education"].fillna("School")
# Out:
# C:\Users\User\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
xvar["education"]=lb_make.fit_transform(xvar["education"])
# Out:
# C:\Users\User\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
xvar["gender"]=lb_make.fit_transform(xvar["gender"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-4bcdd4a46b73> in <module>()
# ----> 1 xvar["gender"]=lb_make.fit_transform(xvar["gender"])
#
# C:\Users\User\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\Users\User\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\Users\User\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
# ...

# %%
xvar["recruitment_channel"]=lb_make.fit_transform(xvar["recruitment_channel"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-324f426c1919> in <module>()
# ----> 1 xvar["recruitment_channel"]=lb_make.fit_transform(xvar["recruitment_channel"])
#
# C:\Users\User\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\Users\User\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\Users\User\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
# ...

# %%
xvar
# Out:
#               department  education  no_of_trainings  age  \
# 0      Sales & Marketing          2                1   35
# 1             Operations          0                1   30
# 2      Sales & Marketing          0                1   34
# 3      Sales & Marketing          0                2   39
# 4             Technology          0                1   45
# 5              Analytics          0                2   31
# 6             Operations          0                1   31
# 7             Operations          2                1   33
# 8              Analytics          0                1   28
# 9      Sales & Marketing          2                1   32
# 10            Technology          3                1   30
# 11     Sales & Marketing          0                1   35
# 12     Sales & Marketing          0                1   49
# 13            Technology          2                2   39
# 14                   R&D          2                1   37
# ...

# %%
xvar["previous_year_rating"].isna().sum()
# Out:
# 4124

# %%
xvar["previous_year_rating"]=xvar["previous_year_rating"].fillna(0)
# Out:
# C:\Users\User\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
xvar["previous_year_rating"].isna().sum()
# Out:
# 0

# %%
xvar["length_of_service"].isna().sum()
# Out:
# 0

# %%
xvar["KPIs_met >80%"].isna().sum()
# Out:
# 0

# %%
xvar["department"]=lb_make.fit_transform(xvar["department"])
# Out:
# C:\Users\User\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
xvar
# Out:
#        department  education  no_of_trainings  age  previous_year_rating  \
# 0               7          2                1   35                   5.0
# 1               4          0                1   30                   5.0
# 2               7          0                1   34                   3.0
# 3               7          0                2   39                   1.0
# 4               8          0                1   45                   3.0
# 5               0          0                2   31                   3.0
# 6               4          0                1   31                   3.0
# 7               4          2                1   33                   3.0
# 8               0          0                1   28                   4.0
# 9               7          2                1   32                   5.0
# 10              8          3                1   30                   0.0
# 11              7          0                1   35                   5.0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
Xtr, Xte, Ytr, Yte = train_test_split(xvar, yvar, test_size=0.33, random_state=32)

# %%
from sklearn import tree

# %%
DTclf = tree.DecisionTreeClassifier()

# %%
DTclf.score(Xte,Yte)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-55-839db5fb2088> in <module>()
# ----> 1 DTclf.score(Xte,Yte)
#
# C:\Users\User\Anaconda2\lib\site-packages\sklearn\base.pyc in score(self, X, y, sample_weight)
#     347         """
#     348         from .metrics import accuracy_score
# --> 349         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     350
#     351
#
# C:\Users\User\Anaconda2\lib\site-packages\sklearn\tree\tree.pyc in predict(self, X, check_input)
#     409             The predicted classes, or the predict values.
#     410         """
# --> 411         check_is_fitted(self, 'tree_')
#     412         X = self._validate_X_predict(X, check_input)
#     413         proba = self.tree_.predict(X)
#
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(Xtr,Ytr)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
logmodel.score(Xte,Yte)
# Out:
# 0.9156300105047824

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
clf = MultinomialNB()

# %%
clf.fit(xvar,yvar)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
clf.score(Xte,Yte)
# Out:
# 0.9156300105047824

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import classification_report

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(xvar,yvar)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc.score(Xte,Yte)
# Out:
# 0.9855697462265716

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(5, 2), random_state=1)

# %%
clf.fit(Xtr,Ytr)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(5, 2), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
clf.score(Xte,Yte)
# Out:
# 0.9156300105047824

# %%
 from sklearn.ensemble import GradientBoostingClassifier

# %%
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,max_depth=1, random_state=0)

# %%
clf.fit(Xtr,Ytr)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=1.0, loss='deviance', max_depth=1,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=0, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
clf.score(Xte,Yte)
# Out:
# 0.9156300105047824

# %%
from sklearn.svm import SVC

# %%
c=SVC()

# %%
c.fit(Xtr,Ytr)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
c.score(Xte,Yte)
# Out:
# 0.9156300105047824

# %% [markdown]
# from sklearn.pipeline import Pipeline

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
pipeline = Pipeline([
    ('normalizer', StandardScaler()), 
    ('clf',KNeighborsClassifier(n_neighbors=3))])

# %%
pipeline.fit(Xtr,Ytr)
# Out:
# Pipeline(memory=None,
#      steps=[('normalizer', StandardScaler(copy=True, with_mean=True, with_std=True)), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform'))])

# %%
pipeline.score(Xte,Yte)
# Out:
# 0.891081992591364

# %%
k=KNeighborsClassifier(n_neighbors=3)

# %%
k.fit(Xtr,Ytr)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
k.score(Xte,Yte)
# Out:
# 0.8973848620556201

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'max_leaf_nodes' : range(1,500,20),'max_depth': range(1,20,2),"max_features":range(1,5),'min_samples_split' : range(10,500,20)}

# %%
param={'n_neighbors':range(1,6)}

# %%
clf=GridSearchCV(k,param_grid=param)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-201-ae24fd918a90> in <module>()
# ----> 1 estimator.get_params().keys()
#
# NameError: name 'estimator' is not defined

# %%
clf.fit(Xtr,Ytr)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_neighbors': [1, 2, 3, 4, 5]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
clf.score(Xte,Yte)
# Out:
# 0.912589152429922

# %%
from sklearn.ensemble import VotingClassifier

# %%
model = VotingClassifier(estimators=[('dt', DTclf), ('kn', k)], voting='hard')

# %%
model.fit(xvar,yvar)
# Out:
# VotingClassifier(estimators=[('dt', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf...owski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform'))],
#          flatten_transform=None, n_jobs=1, voting='hard', weights=None)

# %%
model.score(Xte,Yte)
# Out:
# C:\Users\User\Anaconda2\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.9074473378669763

# %%
from sklearn.ensemble import BaggingClassifier

# %%
model1 = BaggingClassifier(tree.DecisionTreeClassifier(random_state=1))

# %%
model1.fit(xvar,yvar)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=1,
#             splitter='best'),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=10, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)

# %%
model1.score(Xte,Yte)
# Out:
# 0.890142091004589

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
model2 = AdaBoostClassifier(random_state=1)

# %%
model2.fit(Xtr,Ytr)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=1)

# %%
model2.score(Xte,Yte)
# Out:
# 0.9155194338475148

# %%
import xgboost as xg

# %%
clf2 = xg.XGBClassifier(random_state=42,colsample_bytree = 0.9279,gamma = 0.6494,learning_rate = 0.1573,max_depth = 7,min_child_weight = 6,n_estimators = 70,subsample = 0.6404)

# %%
clf2.fit(Xtr,Ytr)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.9279, gamma=0.6494, learning_rate=0.1573,
#        max_delta_step=0, max_depth=7, min_child_weight=6, missing=None,
#        n_estimators=70, n_jobs=1, nthread=None,
#        objective='binary:logistic', random_state=42, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#        subsample=0.6404)

# %%
clf2.score(Xte,Yte)
# Out:
# C:\Users\User\Anaconda2\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.9152429922043457

# %%
clf1 = lgb.LGBMClassifier(max_depth= 8, learning_rate=0.0941, n_estimators=197, num_leaves= 17, reg_alpha=3.4492 , reg_lambda= 0.0422)

# %%
clf1.fit(Xtr,Ytr)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         learning_rate=0.0941, max_depth=8, min_child_samples=20,
#         min_child_weight=0.001, min_split_gain=0.0, n_estimators=197,
#         n_jobs=-1, num_leaves=17, objective=None, random_state=None,
#         reg_alpha=3.4492, reg_lambda=0.0422, silent=True, subsample=1.0,
#         subsample_for_bin=200000, subsample_freq=0)

# %%
clf1.score(Xte,Yte)
# Out:
# C:\Users\User\Anaconda2\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.9156852988334163

# %%
xvar
# Out:
#        region  education  no_of_trainings  age  previous_year_rating  \
# 0          31          2                1   35              5.000000
# 1          14          0                1   30              5.000000
# 2          10          0                1   34              3.000000
# 3          15          0                2   39              1.000000
# 4          18          0                1   45              3.000000
# 5          11          0                2   31              3.000000
# 6          12          0                1   31              3.000000
# 7          27          2                1   33              3.000000
# 8          12          0                1   28              4.000000
# 9           0          2                1   32              5.000000
# 10         15          3                1   30              3.329256
# 11         31          0                1   35              5.000000
# 12         28          0                1   49              5.000000
# ...

# %%
df1=pd.read_csv("wns_test.csv")

# %%
df1.head(15)
# Out:
#     employee_id         department     region         education gender  \
# 0          8724         Technology  region_26        Bachelor's      m
# 1         74430                 HR   region_4        Bachelor's      f
# 2         72255  Sales & Marketing  region_13        Bachelor's      m
# 3         38562        Procurement   region_2        Bachelor's      f
# 4         64486            Finance  region_29        Bachelor's      m
# 5         46232        Procurement   region_7        Bachelor's      m
# 6         54542            Finance   region_2        Bachelor's      m
# 7         67269          Analytics  region_22        Bachelor's      m
# 8         66174         Technology   region_7  Master's & above      m
# 9         76303         Technology  region_22        Bachelor's      m
# 10        60245  Sales & Marketing  region_16        Bachelor's      m
# 11        42639  Sales & Marketing  region_17  Master's & above      m
# ...

# %%
df1["region"]=lb_make.fit_transform(df1["region"])

# %%
df1["department"]=lb_make.fit_transform(df1["department"])

# %%
df1.head(57)
# Out:
#     employee_id  department  region         education gender  \
# 0          8724           8      18        Bachelor's      m
# 1         74430           2      28        Bachelor's      f
# 2         72255           7       4        Bachelor's      m
# 3         38562           5      11        Bachelor's      f
# 4         64486           1      21        Bachelor's      m
# 5         46232           5      31        Bachelor's      m
# 6         54542           1      11        Bachelor's      m
# 7         67269           0      14        Bachelor's      m
# 8         66174           8      31  Master's & above      m
# 9         76303           8      14        Bachelor's      m
# 10        60245           7       7        Bachelor's      m
# 11        42639           7       8  Master's & above      m
# 12        30963           7      28  Master's & above      f
# 13        54055           0      16        Bachelor's      m
# ...

# %%
df1["education"].isna().sum()
# Out:
# 1034

# %%
df1["education"]=df1["education"].fillna("school")

# %%
d={"Bachelor's":0,"Master's & above":2,"school":3,"Below Secondary":1}

# %%
df1["education"]=df1["education"].apply(lambda x:d[x])

# %%
df1["recruitment_channel"]=lb_make.fit_transform(df1["recruitment_channel"])

# %%
df1["gender"]=lb_make.fit_transform(df1["gender"])

# %%
df1["previous_year_rating"]=df1["previous_year_rating"].fillna(0)
df1.head()
# Out:
#    employee_id  department  region  education  gender  recruitment_channel  \
# 0         8724           8      18          0       1                    2
# 1        74430           2      28          0       0                    0
# 2        72255           7       4          0       1                    0
# 3        38562           5      11          0       0                    0
# 4        64486           1      21          0       1                    2
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   24                   0.0                  1
# 1                1   31                   3.0                  5
# 2                1   31                   1.0                  4
# 3                3   31                   2.0                  9
# 4                1   30                   4.0                  7
#
#    KPIs_met >80%  awards_won?  avg_training_score
# 0              1            0                  77
# ...

# %%
Xvar=df1[["department","education","no_of_trainings","age","previous_year_rating","length_of_service","KPIs_met >80%"]]

# %%
pr=model1.predict(Xvar)

# %%
df_1=pd.DataFrame(df1["employee_id"])

# %%
df_2=pd.DataFrame(pr,columns=["is_promoted"])

# %%
d=pd.merge(df_1,df_2,left_index=True,right_index=True)

# %%
import lightgbm as lgb

# %%
d
# Out:
#        employee_id  is_promoted
# 0             8724            0
# 1            74430            0
# 2            72255            0
# 3            38562            0
# 4            64486            0
# 5            46232            0
# 6            54542            0
# 7            67269            0
# 8            66174            0
# 9            76303            0
# 10           60245            0
# 11           42639            0
# 12           30963            0
# 13           54055            0
# 14           42996            0
# 15           12737            0
# 16           27561            0
# 17           26622            0
# 18           31582            0
# 19           29793            0
# 20           72735            0
# 21            5677            0
# 22           60889            0
# 23           51498            0
# 24            8566            0
# 25           53151            0
# 26           16203            0
# 27           61083            0
# ...

# %%
d.to_csv("submit_711.csv",index=False)

# %%
k.to_csv("submit1.csv")
